# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
incomes = np.random.normal(100.0, 20.0, 10000)
plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 20.009116310720646

# %%
incomes.var()
# Out:
# 400.36473553594703
